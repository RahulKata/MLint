# %%
from PIL import Image,ImageFile
from matplotlib.pyplot import imshow
import requests
from io import BytesIO
import numpy as np

# %%
url = "https://ca-times.brightspotcdn.com/dims4/default/e5ae987/2147483647/strip/true/crop/4758x3172+0+0/resize/1486x991!/quality/90/?url=https%3A%2F%2Fcalifornia-times-brightspot.s3.amazonaws.com%2F2a%2Fef%2F51d8dfcb4e3b87b34ddc529c8c38%2Fhttps-delivery.gettyimages.com%2Fdownloads%2F1210245387.jpg"

response = requests.get(url)
img = Image.open(BytesIO(response.content))
img.load()

print(np.asarray(img))

img
# Out:
# [[[59 64 70]
#   [58 63 69]
#   [57 62 68]
#   ...
#   [15 16 20]
#   [15 16 20]
#   [15 16 20]]
#
#  [[58 63 69]
#   [57 62 68]
#   [56 61 67]
#   ...
#   [15 16 20]
#   [15 16 20]
#   [15 16 20]]
#
#  [[57 62 68]
#   [56 61 67]
#   [56 61 67]
#   ...
#   [13 17 20]
#   [13 17 20]
#   [13 17 20]]
#
#  ...
#
#  [[ 5  7  6]
#   [ 6  8  7]
#   [ 6  8  7]
#   ...
#   [35 34 32]
#   [40 39 37]
#   [45 44 42]]
#
#  [[ 5  7  6]
#   [ 6  8  7]
#   [ 6  8  7]
#   ...
#   [33 32 30]
#   [38 37 35]
#   [44 43 41]]
#
#  [[ 5  7  6]
#   [ 5  7  6]
#   [ 6  8  7]
#   ...
#   [31 30 28]
#   [36 35 33]
#   [43 42 40]]]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1486x991 at 0x1FAC4289F08>

# %% [markdown]
# <hr>
# You can create an image in python from number(pixels)
